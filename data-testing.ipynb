# %% [markdown]
# * Predictive Maintenance

# %%
from all_imports import *
from pipeline import *
from variables import *

# %%
pd.read_csv(f"{data_directory}/logistics_dataset_with_maintenance_required.csv")
# Out:
#        Vehicle_ID   Make_and_Model  Year_of_Manufacture Vehicle_Type  \
# 0               1       Ford F-150                 2022        Truck
# 1               2         Volvo FH                 2015          Van
# 2               3  Chevy Silverado                 2022          Van
# 3               4  Chevy Silverado                 2011        Truck
# 4               5       Ford F-150                 2014          Van
# ...           ...              ...                  ...          ...
# 91995       91996  Chevy Silverado                 2022          Van
# 91996       91997       Ford F-150                 2006        Truck
# 91997       91998       Tesla Semi                 2020          Van
# 91998       91999       Tesla Semi                 2022        Truck
# 91999       92000       Ford F-150                 2020          Van
#
#        Usage_Hours Route_Info  Load_Capacity  Actual_Load  \
# 0              530      Rural       7.534549     9.004247
# ...

# %%
pd.read_csv(f"{data_directory}/Bus_Breakdown_and_Delays.csv")
# Out:
# C:\Users\Nicholas Vaill\AppData\Local\Temp\ipykernel_4940\82928893.py:1: DtypeWarning: Columns (5,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(f"{data_directory}/Bus_Breakdown_and_Delays.csv")
#         School_Year  Busbreakdown_ID           Run_Type  Bus_No Route_Number  \
# 0         2015-2016          1272996  Special Ed AM Run    2256         K355
# 1         2016-2017          1313907  Special Ed AM Run    4481         K002
# 2         2015-2016          1267391  Special Ed AM Run  GT2114         Y925
# 3         2016-2017          1312240  General Ed AM Run    2436        K1546
# 4         2016-2017          1312351  Special Ed AM Run   5814D         X441
# ...             ...              ...                ...     ...          ...
# 1235300   2025-2026          2018107  Special Ed AM Run   24631         X019
# 1235301   2025-2026          2018108  Special Ed AM Run   74618         X023
# ...
